# %%
# Set up the packages
#! pip install numpy
#! pip install pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Demo the libraries numpy and pandas using short quick examples. In the comments include notes on all the steps, a short description of the library, the core features of the library, and its applications to graduate economics study.

# %%
# Load the wage csv file
path = r'D:\william\OneDrive - UW-Madison\UW-Madison\722\MachineLearning25'
df = pd.read_csv(path + '/wage.csv')

# %%
# Display the labels of the dataframe
df.columns
# Out:
# Index(['year', 'age', 'maritl', 'race', 'education', 'region', 'jobclass',
#        'health', 'health_ins', 'logwage', 'wage'],
#       dtype='object')

# %%
# Creat a scatter plot of wage vs age
plt.scatter(df['age'], df['wage'])
plt.xlabel('Age')
plt.ylabel('Wage')
plt.title('Scatter plot of Wage vs Age')
plt.show()
